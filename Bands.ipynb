# %% [markdown]
# # Erik´s Metal Bands

# %%
import pandas as pd

# %%
bands = pd.read_csv("finishedbands.csv")

# %%
import seaborn as sns

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Fixing Data

# %%
pd.set_option('display.max_rows', None)

# %%
bands.drop(bands.loc[bands['Year Formed']==0].index, inplace=True)

# %%
bands[bands["Year Formed"] == 2021]
# Out:
# Empty DataFrame
# Columns: [ID, Band Name, Genre, Year Formed, Founded In, Country, N° of Albums, N° of Singles, Newest Album, Year, N°1 Most Popular Album, 2° Most Popular Album, 3° Most Popular Album, Top Song, 2° Top Song, 3° Top Song, 4° Top Song, 5° Top Song, Spotify Listeners, In tour?, When?, Where?]
# Index: []
#
# [0 rows x 22 columns]

# %%
bands["Bands Formed"] = bands['Year Formed'].value_counts()

# %%
bands['Year Formed'].value_counts().max()
# Out:
# 8

# %%
bands
# Out:
#       ID        Band Name                                     Genre  \
# 0      1         Abichova                       Melodic Death Metal
# 1      2    Adorned Brood                                Folk Metal
# 2      3         Alestorm                          Folk/Power Metal
# 3      4  Altars of Grief                  Black/Funeral Doom Metal
# 4      5     Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal
# ..   ...              ...                                       ...
# 119  120           Wisdom                               Power Metal
# 120  121           Wizard                          Epic Power Metal
# 121  122        Wolfchant                          Pagan/Folk Metal
# 122  123        Wolfheart                       Melodic Death Metal
# 123  124          Wulfgar                       Melodic Death Metal
#
#      Year Formed                   Founded In         Country  N° of Albums  \
# ...

# %%
missing_bands =[{"ID": "", 
    "Band Name" : "Sabaton",
    "Genre" : "Power Metal/Historic Metal", 
    "Year Formed": "1993",
    "Founded In": "Falu, SE",
    "Country": "Sweden",
    "N° of Albums": "11",
    "N° of Singles": "27",
    "Newest Album": "The Symphony to End All Wars",
    "Year": "2022",
    "N°1 Most Popular Album": "The Great War",
    "2° Most Popular Album": "Primo Victoria",
    "3° Most Popular Album": "The Last Stand",
    "Top Song": "Bismarck",
    "2° Top Song": "Stormtroopers",
    "3° Top Song": "Panzer Battalion",
    "4° Top Song": "To Hell and Back",
    "5° Top Song": "Primo Victoria",
    "Spotify Listeners": "2653268",
    "In tour?": "Yes",
    "When?": "2022",
    "Where?": "US"},
    {"ID": "", 
    "Band Name" : "Stratovarius",
    "Genre" : "Melodic Power Metal", 
    "Year Formed": "1985",
    "Founded In": "Helsinki, FI",
    "Country": "Finland",
    "N° of Albums": "17",
    "N° of Singles": "21",
    "Newest Album": "Survive",
    "Year": "2022",
    "N°1 Most Popular Album": "Elements Pt. 1",
    "2° Most Popular Album": "Elements Pt. 2",
    "3° Most Popular Album": "Twilight Time",
    "Top Song": "Hunting High and Low",
    "2° Top Song": "Black Diamond",
    "3° Top Song": "Unbreakable",
    "4° Top Song": "Eagleheart",
    "5° Top Song": "Stratosphere",
    "Spotify Listeners": "924680",
    "In tour?": "Yes",
    "When?": "2022",
    "Where?": "EU"},
        {"ID": "", 
    "Band Name" : "Battle Beast",
    "Genre" : "", 
    "Year Formed": "",
    "Founded In": "",
    "Country": "",
    "N° of Albums": "",
    "N° of Singles": "",
    "Newest Album": "",
    "Year": "",
    "N°1 Most Popular Album": "",
    "2° Most Popular Album": "",
    "3° Most Popular Album": "",
    "Top Song": "",
    "2° Top Song": "",
    "3° Top Song": "",
    "4° Top Song": "",
    "5° Top Song": "",
    "Spotify Listeners": "",
    "In tour?": "",
    "When?": "",
    "Where?": ""}]

# %% [markdown]
# #### Add Missing Bands with .append()

# %%
bands_complete_append = bands.append(missing_bands)
# Out:
# C:\Users\ehub9_\AppData\Local\Temp\ipykernel_17184\2619565847.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   bands_complete_append = bands.append(missing_bands)

# %%
bands_complete_append
# Out:
#       ID        Band Name                                     Genre  \
# 0      1         Abichova                       Melodic Death Metal
# 1      2    Adorned Brood                                Folk Metal
# 2      3         Alestorm                          Folk/Power Metal
# 3      4  Altars of Grief                  Black/Funeral Doom Metal
# 4      5     Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal
# ..   ...              ...                                       ...
# 120  120          Wulfgar                       Melodic Death Metal
# 121  122     Freedom Call                               Power Metal
# 0                 Sabaton                Power Metal/Historic Metal
# 1            Stratovarius                       Melodic Power Metal
# 2            Battle Beast
#
#     Year Formed        Founded In         Country N° of Albums N° of Singles  \
# 0         2005        Lucerne, CH     Switzerland          3.0           4.0
# ...

# %% [markdown]
# #### Add Missing Bands with .concat()

# %%
missing_bands_pd=pd.DataFrame (missing_bands, columns = ["ID", "Band Name", "Genre", "Year Formed", "Founded In", "Country", "N° of Albums",
    "N° of Singles", "Newest Album", "Year", "N°1 Most Popular Album", "2° Most Popular Album",
    "3° Most Popular Album", "Top Song",  "2° Top Song", "3° Top Song", "4° Top Song", "5° Top Song",
    "Spotify Listeners", "In tour?", "When?", "Where?"])
bands_pd=pd.DataFrame(bands)
bands_complete_concat = [bands_pd, missing_bands_pd]
pd.concat(bands_complete_concat)
# Out:
#       ID        Band Name                                     Genre  \
# 0      1         Abichova                       Melodic Death Metal
# 1      2    Adorned Brood                                Folk Metal
# 2      3         Alestorm                          Folk/Power Metal
# 3      4  Altars of Grief                  Black/Funeral Doom Metal
# 4      5     Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal
# ..   ...              ...                                       ...
# 120  120          Wulfgar                       Melodic Death Metal
# 121  122     Freedom Call                               Power Metal
# 0                 Sabaton                Power Metal/Historic Metal
# 1            Stratovarius                       Melodic Power Metal
# 2            Battle Beast
#
#     Year Formed        Founded In         Country N° of Albums N° of Singles  \
# 0         2005        Lucerne, CH     Switzerland          3.0           4.0
# ...

# %%
bands = bands_complete_append

# %%
bands
# Out:
#       ID        Band Name                                     Genre  \
# 0      1         Abichova                       Melodic Death Metal
# 1      2    Adorned Brood                                Folk Metal
# 2      3         Alestorm                          Folk/Power Metal
# 3      4  Altars of Grief                  Black/Funeral Doom Metal
# 4      5     Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal
# ..   ...              ...                                       ...
# 120  120          Wulfgar                       Melodic Death Metal
# 121  122     Freedom Call                               Power Metal
# 0                 Sabaton                Power Metal/Historic Metal
# 1            Stratovarius                       Melodic Power Metal
# 2            Battle Beast
#
#     Year Formed        Founded In         Country N° of Albums N° of Singles  \
# 0         2005        Lucerne, CH     Switzerland          3.0           4.0
# ...

# %% [markdown]
# #### Remove ID column

# %%
bands.drop('ID', axis=1, inplace=True)

# %%
bands
# Out:
#            Band Name                                     Genre  Year Formed  \
# 0           Abichova                       Melodic Death Metal         2005
# 1      Adorned Brood                                Folk Metal         1993
# 2           Alestorm                          Folk/Power Metal         2007
# 3    Altars of Grief                  Black/Funeral Doom Metal         2013
# 4       Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal         2004
# ..               ...                                       ...          ...
# 120           Wizard                          Epic Power Metal         1989
# 121        Wolfchant                          Pagan/Folk Metal         2003
# 122        Wolfheart                       Melodic Death Metal         2013
# 123          Wulfgar                       Melodic Death Metal         2005
# 124       Übermensch                  Metalcore/Historic Metal            0
#
# ...

# %% [markdown]
# #### Sort Bands Alphabetically

# %%
bands = bands.sort_values('Band Name')

# %%
bands
# Out:
#            Band Name                                     Genre Year Formed  \
# 0           Abichova                       Melodic Death Metal       2005
# 1      Adorned Brood                                Folk Metal       1993
# 2           Alestorm                          Folk/Power Metal       2007
# 3    Altars of Grief                  Black/Funeral Doom Metal       2013
# 4       Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal       2004
# ..               ...                                       ...         ...
# 117           Wizard                          Epic Power Metal        1989
# 118        Wolfchant                          Pagan/Folk Metal        2003
# 119        Wolfheart                       Melodic Death Metal        2013
# 120          Wulfgar                       Melodic Death Metal        2005
# 89        Übermensch                  Metalcore/Historic Metal         NaN
#
# ...

# %% [markdown]
# #### Add ID column with new index

# %%
bands.reset_index(drop=True, inplace=True)

# %%
bands.insert(0, 'ID', (range(1, len(bands) + 1)))

# %%
bands.set_index("ID", inplace=True)

# %% [markdown]
# #### Change Index to ID

# %%
bands
# Out:
#            Band Name                                     Genre Year Formed  \
# ID
# 1           Abichova                       Melodic Death Metal       2005
# 2      Adorned Brood                                Folk Metal       1993
# 3           Alestorm                          Folk/Power Metal       2007
# 4    Altars of Grief                  Black/Funeral Doom Metal       2013
# 5       Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal       2004
# ..               ...                                       ...         ...
# 121           Wizard                          Epic Power Metal        1989
# 122        Wolfchant                          Pagan/Folk Metal        2003
# 123        Wolfheart                       Melodic Death Metal        2013
# 124          Wulfgar                       Melodic Death Metal        2005
# 125       Übermensch                  Metalcore/Historic Metal         NaN
#
# ...

# %% [markdown]
# #### Updating missing values for Band "Battle Beast"

# %%
bands[bands["Band Name"] == "Battle Beast"]
# Out:
#    ID     Band Name              Genre  Year Formed    Founded In  Country  \
# 9  10  Battle Beast  Heavy/Power Metal         2005  Helsinki, FL  Finland
#
#    N° of Albums  N° of Singles    Newest Album  Year  ...  \
# 9             6              6  Circus of Doom  2022  ...
#
#   3° Most Popular Album        Top Song 2° Top Song            3° Top Song  \
# 9         Unholy Savior  King for a Day        Eden  Straight to the Heart
#
#                  4° Top Song         5° Top Song Spotify Listeners In tour?  \
# 9  No More Hollywood Endings  Master of Illusion            758216      Yes
#
#    When? Where?
# 9   2022  EU/US
#
# [1 rows x 22 columns]

# %%
bands.loc[[121]]
# Out:
#     Band Name             Genre Year Formed   Founded In  Country  \
# ID
# 121    Wizard  Epic Power Metal        1989  Bocholt, DE  Germany
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 121         12.0           0.0  Metal in My Head  2121                   Thor
#
#      ... 3° Most Popular Album           Top Song       2° Top Song  \
# ID   ...
# 121  ...                  Odin  Midgards Guardian  Metal in My Head
#
#                      3° Top Song        4° Top Song  5° Top Song  \
# ID
# 121  I Bring Lught Into the Dark  Liar and Betrayer  Metal Feast
#
#     Spotify Listeners In tour? When? Where?
# ID
# 121             15840       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[121, ["Year"]] = ["2021"]

# %%
bands.loc[[121]]
# Out:
#     Band Name             Genre Year Formed   Founded In  Country  \
# ID
# 121    Wizard  Epic Power Metal        1989  Bocholt, DE  Germany
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 121         12.0           0.0  Metal in My Head  2021                   Thor
#
#      ... 3° Most Popular Album           Top Song       2° Top Song  \
# ID   ...
# 121  ...                  Odin  Midgards Guardian  Metal in My Head
#
#                      3° Top Song        4° Top Song  5° Top Song  \
# ID
# 121  I Bring Lught Into the Dark  Liar and Betrayer  Metal Feast
#
#     Spotify Listeners In tour? When? Where?
# ID
# 121             15840       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[10]]
# Out:
#        Band Name Genre Year Formed Founded In Country N° of Albums  \
# ID
# 10  Battle Beast
#
#    N° of Singles Newest Album Year N°1 Most Popular Album  ...  \
# ID                                                         ...
# 10                                                         ...
#
#    3° Most Popular Album Top Song 2° Top Song 3° Top Song 4° Top Song  \
# ID
# 10
#
#    5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 10
#
# [1 rows x 21 columns]

# %%
bands.loc[10, ["Genre", "Year Formed", "Founded In", "Country", "N° of Albums",
    "N° of Singles", "Newest Album", "Year", "N°1 Most Popular Album", "2° Most Popular Album",
    "3° Most Popular Album", "Top Song",  "2° Top Song", "3° Top Song", "4° Top Song", "5° Top Song",
    "Spotify Listeners", "In tour?", "When?", "Where?"]] = ["Heavy/Power Metal", "2005", "Helsinki, FL", "Finland", "6", "6", "Circus of Doom", "2022", "Steel", " Battle Beast", "Unholy Savior", "King for a Day", "Eden", "Straight to the Heart", "No More Hollywood Endings", "Master of Illusion", "758216", "Yes", "2022", "USA/EU"]

# %%
bands.loc[[10]]
# Out:
#        Band Name              Genre Year Formed    Founded In  Country  \
# ID
# 10  Battle Beast  Heavy/Power Metal        2005  Helsinki, FL  Finland
#
#    N° of Albums N° of Singles    Newest Album  Year N°1 Most Popular Album  \
# ID
# 10            6             6  Circus of Doom  2022                  Steel
#
#     ... 3° Most Popular Album        Top Song 2° Top Song  \
# ID  ...
# 10  ...         Unholy Savior  King for a Day        Eden
#
#               3° Top Song                4° Top Song         5° Top Song  \
# ID
# 10  Straight to the Heart  No More Hollywood Endings  Master of Illusion
#
#    Spotify Listeners In tour? When?  Where?
# ID
# 10            758216      Yes  2022  USA/EU
#
# [1 rows x 21 columns]

# %% [markdown]
# #### Fix data

# %%
bands.loc[bands['Founded In'] =='Copenhagen, DE']
# Out:
#     Band Name                 Genre Year Formed      Founded In  \
# ID
# 60    Heilung  Neo Folk/Euro Ethnic        2014  Copenhagen, DE
# 106       Týr            Folk Metal        1998  Copenhagen, DE
#
#                          Country N° of Albums N° of Singles Newest Album  \
# ID
# 60   Denmark, Germany and Norway          4.0           0.0         Lifa
# 106        Denmark/Faroe Islands          8.0           0.0          Hel
#
#      Year             N°1 Most Popular Album  ... 3° Most Popular Album  \
# ID                                            ...
# 60   2017                              Futha  ...                 Ofnir
# 106  2019  By the Light of the Northern Star  ...              Ragnarok
#
#             Top Song                   2° Top Song              3° Top Song  \
# ID
# 60     Hakkerskaldyr                    Krigsgaldr                    Anona
# 106  Blood of Hereos  Hold the Heathen Hammer High  By the Sword in My Hand
#
# ...

# %%
bands.loc[[103]]
# Out:
#         Band Name                Genre Year Formed Founded In  Country  \
# ID
# 103  The Declawed  Melodic Death Metal        2020  Kotka, FI  Finland
#
#     N° of Albums N° of Singles Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                                        ...
# 103          1.0           0.0        Howls  2020                  Howls  ...
#
#     3° Most Popular Album Top Song     2° Top Song              3° Top Song  \
# ID
# 103                   NaN    Howls  Cynical Resign  The Great Mist Of a Lie
#
#            4° Top Song 5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 103  Circle Of Entropy         NaN                 6       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[103, ["Founded In"]] = ["Copenhagen, DK"]

# %%
bands.loc[59, ["Founded In"]] = ["Copenhagen, DK"]

# %%
bands.loc[bands['Band Name'] =='Heljareyga']
# Out:
#      Band Name                   Genre   Year Formed Founded In  \
# ID
# 62  Heljareyga  Folk/Progressive Metal  Runavík, FO        2009
#
#                   Country N° of Albums N° of Singles Newest Album  Year  \
# ID
# 62  Faroe Islands/Denmark          1.0           0.0   Heljareyga  2010
#
#    N°1 Most Popular Album  ... 3° Most Popular Album Top Song 2° Top Song  \
# ID                         ...
# 62             Heljareyga  ...                   NaN   Regnið  Heljareyga
#
#    3° Top Song    4° Top Song 5° Top Song Spotify Listeners In tour? When?  \
# ID
# 62     Feigdin  Vetrarbreytin      Lagnan               343       No   NaN
#
#    Where?
# ID
# 62    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[61, ["Year Formed", "Founded In"]] = ["2009","Runavík, FO"]

# %%
bands.loc[[61]]
# Out:
#      Band Name        Genre Year Formed   Founded In  Country N° of Albums  \
# ID
# 61  Helgrindur  Pagan Metal        2009  Runavík, FO  Germany          1.0
#
#    N° of Singles Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                          ...
# 61           0.0    Von einst  2017              Von einst  ...
#
#    3° Most Popular Album      Top Song 2° Top Song 3° Top Song 4° Top Song  \
# ID
# 61                   NaN  Grimus Fluch    Gotenzug   Von Einst    Aufbruch
#
#    5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 61   Lügenbold               200       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[102, ["Founded In"]] = ["Randers, DK"]

# %%
bands.loc[[102]]
# Out:
#     Band Name       Genre Year Formed   Founded In  Country N° of Albums  \
# ID
# 102  Svartsot  Folk Metal        2005  Randers, DK  Denmark          5.0
#
#     N° of Singles Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                           ...
# 102           1.0        Kumbl  2022          Ravnenes saga  ...
#
#     3° Most Popular Album   Top Song 2° Top Song         3° Top Song  \
# ID
# 102                Vældet  Gravollet   Midsommer  Drømte mig en drøm
#
#        4° Top Song   5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 102  Rottefængeren  Tvende Ravne             17894      Yes  2023     EU
#
# [1 rows x 21 columns]

# %%
bands.loc[bands['Country'] =='Germnay']
# Out:
#        Band Name             Genre Year Formed    Founded In  Country  \
# ID
# 118  Winterstorm  Power/Folk Metal        2008  Bayreuth, DE  Germnay
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 118          4.0           0.0  Cube of Infinity  2016        Kings Will Fall
#
#      ... 3° Most Popular Album         Top Song        2° Top Song  \
# ID   ...
# 118  ...              Cathyron  Kings Will Fall  Through the Storm
#
#          3° Top Song               4° Top Song       5° Top Song  \
# ID
# 118  Return to Glory  Pacts of Blood and Might  In Time We Trust
#
#     Spotify Listeners In tour? When? Where?
# ID
# 118             15331       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[115, ["Country"]] = ["Germany"]

# %%
bands.loc[118, ["Country"]] = ["Germany"]

# %%
bands.loc[[118]]
# Out:
#        Band Name             Genre Year Formed    Founded In  Country  \
# ID
# 118  Winterstorm  Power/Folk Metal        2008  Bayreuth, DE  Germany
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 118          4.0           0.0  Cube of Infinity  2016        Kings Will Fall
#
#      ... 3° Most Popular Album         Top Song        2° Top Song  \
# ID   ...
# 118  ...              Cathyron  Kings Will Fall  Through the Storm
#
#          3° Top Song               4° Top Song       5° Top Song  \
# ID
# 118  Return to Glory  Pacts of Blood and Might  In Time We Trust
#
#     Spotify Listeners In tour? When? Where?
# ID
# 118             15331       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[64]]
# Out:
#    Band Name             Genre Year Formed  Founded In Country N° of Albums  \
# ID
# 64   Helroth  Pagan/Folk Metal        2012  Warsaw, PL  Poland          1.0
#
#    N° of Singles Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                          ...
# 64           0.0     I, Pagan  2016               I, Pagan  ...
#
#    3° Most Popular Album Top Song 2° Top Song 3° Top Song  4° Top Song  \
# ID
# 64                   NaN    Ortni      Mamuny       Kwiat  Kwiat zycia
#
#       5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 64  Wilcza jagoda             12751       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[64, ["Year"]] = ["2020"]

# %%
bands.loc[[64]]
# Out:
#    Band Name             Genre Year Formed  Founded In Country N° of Albums  \
# ID
# 64   Helroth  Pagan/Folk Metal        2012  Warsaw, PL  Poland          1.0
#
#    N° of Singles Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                          ...
# 64           0.0     I, Pagan  2020               I, Pagan  ...
#
#    3° Most Popular Album Top Song 2° Top Song 3° Top Song  4° Top Song  \
# ID
# 64                   NaN    Ortni      Mamuny       Kwiat  Kwiat zycia
#
#       5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 64  Wilcza jagoda             12751       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[65, ["Year"]] = ["2021"]

# %%
bands.loc[[65]]
# Out:
#       Band Name     Genre Year Formed     Founded In Country N° of Albums  \
# ID
# 65  Hindarfjäll  Neo Folk        2019  Stockholm, SE  Sweden          2.0
#
#    N° of Singles   Newest Album  Year N°1 Most Popular Album  ...  \
# ID                                                            ...
# 65           0.0  Lärads Grenar  2021          Lärads Grenar  ...
#
#    3° Most Popular Album                        Top Song  \
# ID
# 65                   NaN  Så Som Träden Viskar Hans Namn
#
#                  2° Top Song     3° Top Song            4° Top Song  \
# ID
# 65  Från Tidernas Begynnelse  Sunnas Strålar  Skogen Kallar Mig Hem
#
#       5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 65  Hjulet Vänder             24735       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[62]]
# Out:
#      Band Name                   Genre   Year Formed Founded In  \
# ID
# 62  Heljareyga  Folk/Progressive Metal  Runavík, FO        2009
#
#                   Country N° of Albums N° of Singles Newest Album  Year  \
# ID
# 62  Faroe Islands/Denmark          1.0           0.0   Heljareyga  2010
#
#    N°1 Most Popular Album  ... 3° Most Popular Album Top Song 2° Top Song  \
# ID                         ...
# 62             Heljareyga  ...                   NaN   Regnið  Heljareyga
#
#    3° Top Song    4° Top Song 5° Top Song Spotify Listeners In tour? When?  \
# ID
# 62     Feigdin  Vetrarbreytin      Lagnan               343       No   NaN
#
#    Where?
# ID
# 62    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[62, ["Year Formed", "Founded In"]] = ["1983", "Hamburg, DE"]

# %%
bands.loc[[62]]
# Out:
#      Band Name                   Genre Year Formed   Founded In  \
# ID
# 62  Heljareyga  Folk/Progressive Metal        1983  Hamburg, DE
#
#                   Country N° of Albums N° of Singles Newest Album  Year  \
# ID
# 62  Faroe Islands/Denmark          1.0           0.0   Heljareyga  2010
#
#    N°1 Most Popular Album  ... 3° Most Popular Album Top Song 2° Top Song  \
# ID                         ...
# 62             Heljareyga  ...                   NaN   Regnið  Heljareyga
#
#    3° Top Song    4° Top Song 5° Top Song Spotify Listeners In tour? When?  \
# ID
# 62     Feigdin  Vetrarbreytin      Lagnan               343       No   NaN
#
#    Where?
# ID
# 62    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[bands['Year Formed'] =='Tampere, FI']
# Out:
#     Band Name                Genre  Year Formed Founded In  Country  \
# ID
# 34  Dreamtale  Melodic Power Metal  Tampere, FI       1999  Finland
#
#    N° of Albums N° of Singles       Newest Album  Year  \
# ID
# 34          8.0           5.0  Everlasting Flame  2022
#
#             N°1 Most Popular Album  ... 3° Most Popular Album        Top Song  \
# ID                                  ...
# 34  Seventhian... Memories of Time  ...     Everlasting Flame  Angel Of Light
#
#          2° Top Song   3° Top Song 4° Top Song                   5° Top Song  \
# ID
# 34  Greenback Hunter  Tides of War    Dreality  Take What the Heavens Cerate
#
#    Spotify Listeners In tour? When? Where?
# ID
# 34             51234       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[33]]
# Out:
#       Band Name                Genre Year Formed     Founded In  Country  \
# ID
# 33  Dragonsifre  Melodic Heavy Metal        2005  Riedstadt, DE  Germany
#
#    N° of Albums N° of Singles           Newest Album  Year  \
# ID
# 33          3.0           1.0  Speed Demon / Metal X  2015
#
#         N°1 Most Popular Album  ... 3° Most Popular Album     Top Song  \
# ID                              ...
# 33  Masters of the Underground  ...         Metal Service  Speed Demon
#
#          2° Top Song         3° Top Song     4° Top Song   5° Top Song  \
# ID
# 33  To Hell and Back  Drgansfire Rockxxx  Wings of Death  Morris Tunes
#
#    Spotify Listeners In tour? When? Where?
# ID
# 33               385       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[33, ["Year Formed", "Founded In"]] = ["1999", "Tampere, FI"]

# %%
bands.loc[[33]]
# Out:
#       Band Name                Genre Year Formed   Founded In  Country  \
# ID
# 33  Dragonsifre  Melodic Heavy Metal        1999  Tampere, FI  Germany
#
#    N° of Albums N° of Singles           Newest Album  Year  \
# ID
# 33          3.0           1.0  Speed Demon / Metal X  2015
#
#         N°1 Most Popular Album  ... 3° Most Popular Album     Top Song  \
# ID                              ...
# 33  Masters of the Underground  ...         Metal Service  Speed Demon
#
#          2° Top Song         3° Top Song     4° Top Song   5° Top Song  \
# ID
# 33  To Hell and Back  Drgansfire Rockxxx  Wings of Death  Morris Tunes
#
#    Spotify Listeners In tour? When? Where?
# ID
# 33               385       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[106]]
# Out:
#     Band Name       Genre Year Formed      Founded In                Country  \
# ID
# 106       Týr  Folk Metal        1998  Copenhagen, DE  Denmark/Faroe Islands
#
#     N° of Albums N° of Singles Newest Album  Year  \
# ID
# 106          8.0           0.0          Hel  2019
#
#                 N°1 Most Popular Album  ... 3° Most Popular Album  \
# ID                                      ...
# 106  By the Light of the Northern Star  ...              Ragnarok
#
#             Top Song                   2° Top Song              3° Top Song  \
# ID
# 106  Blood of Hereos  Hold the Heathen Hammer High  By the Sword in My Hand
#
#         4° Top Song      5° Top Song Spotify Listeners In tour? When? Where?
# ID
# 106  Ragnars kvæði   Cementery Gates            210517      Yes  2022     EU
#
# [1 rows x 21 columns]

# %%
bands.loc[106, ["Founded In"]] = ["Copenhagen, DK"]

# %%
bands.loc[[34]]
# Out:
#     Band Name                Genre  Year Formed Founded In  Country  \
# ID
# 34  Dreamtale  Melodic Power Metal  Tampere, FI       1999  Finland
#
#    N° of Albums N° of Singles       Newest Album  Year  \
# ID
# 34          8.0           5.0  Everlasting Flame  2022
#
#             N°1 Most Popular Album  ... 3° Most Popular Album        Top Song  \
# ID                                  ...
# 34  Seventhian... Memories of Time  ...     Everlasting Flame  Angel Of Light
#
#          2° Top Song   3° Top Song 4° Top Song                   5° Top Song  \
# ID
# 34  Greenback Hunter  Tides of War    Dreality  Take What the Heavens Cerate
#
#    Spotify Listeners In tour? When? Where?
# ID
# 34             51234       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[34, ["Year Formed", "Founded In"]] = ["2012", ", NJ"]

# %%
bands.loc[[34]]
# Out:
#     Band Name                Genre Year Formed Founded In  Country  \
# ID
# 34  Dreamtale  Melodic Power Metal        2012       , NJ  Finland
#
#    N° of Albums N° of Singles       Newest Album  Year  \
# ID
# 34          8.0           5.0  Everlasting Flame  2022
#
#             N°1 Most Popular Album  ... 3° Most Popular Album        Top Song  \
# ID                                  ...
# 34  Seventhian... Memories of Time  ...     Everlasting Flame  Angel Of Light
#
#          2° Top Song   3° Top Song 4° Top Song                   5° Top Song  \
# ID
# 34  Greenback Hunter  Tides of War    Dreality  Take What the Heavens Cerate
#
#    Spotify Listeners In tour? When? Where?
# ID
# 34             51234       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands
# Out:
#            Band Name                                     Genre Year Formed  \
# ID
# 1           Abichova                       Melodic Death Metal       2005
# 2      Adorned Brood                                Folk Metal       1993
# 3           Alestorm                          Folk/Power Metal       2007
# 4    Altars of Grief                  Black/Funeral Doom Metal       2013
# 5       Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal       2004
# ..               ...                                       ...         ...
# 121           Wizard                          Epic Power Metal        1989
# 122        Wolfchant                          Pagan/Folk Metal        2003
# 123        Wolfheart                       Melodic Death Metal        2013
# 124          Wulfgar                       Melodic Death Metal        2005
# 125       Übermensch                  Metalcore/Historic Metal         NaN
#
# ...

# %%
bands.loc[[34]]
# Out:
#     Band Name                Genre Year Formed Founded In  Country  \
# ID
# 34  Dreamtale  Melodic Power Metal        2012       , NJ  Finland
#
#    N° of Albums N° of Singles       Newest Album  Year  \
# ID
# 34          8.0           5.0  Everlasting Flame  2022
#
#             N°1 Most Popular Album  ... 3° Most Popular Album        Top Song  \
# ID                                  ...
# 34  Seventhian... Memories of Time  ...     Everlasting Flame  Angel Of Light
#
#          2° Top Song   3° Top Song 4° Top Song                   5° Top Song  \
# ID
# 34  Greenback Hunter  Tides of War    Dreality  Take What the Heavens Cerate
#
#    Spotify Listeners In tour? When? Where?
# ID
# 34             51234       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[[118]]
# Out:
#        Band Name             Genre Year Formed    Founded In  Country  \
# ID
# 118  Winterstorm  Power/Folk Metal        2008  Bayreuth, DE  Germany
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 118          4.0           0.0  Cube of Infinity  2016        Kings Will Fall
#
#      ... 3° Most Popular Album         Top Song        2° Top Song  \
# ID   ...
# 118  ...              Cathyron  Kings Will Fall  Through the Storm
#
#          3° Top Song               4° Top Song       5° Top Song  \
# ID
# 118  Return to Glory  Pacts of Blood and Might  In Time We Trust
#
#     Spotify Listeners In tour? When? Where?
# ID
# 118             15331       No   NaN    NaN
#
# [1 rows x 21 columns]

# %%
bands.loc[118, ["Year"]] = ["2021"]

# %%
bands.loc[[118]]
# Out:
#        Band Name             Genre Year Formed    Founded In  Country  \
# ID
# 118  Winterstorm  Power/Folk Metal        2008  Bayreuth, DE  Germany
#
#     N° of Albums N° of Singles      Newest Album  Year N°1 Most Popular Album  \
# ID
# 118          4.0           0.0  Cube of Infinity  2021        Kings Will Fall
#
#      ... 3° Most Popular Album         Top Song        2° Top Song  \
# ID   ...
# 118  ...              Cathyron  Kings Will Fall  Through the Storm
#
#          3° Top Song               4° Top Song       5° Top Song  \
# ID
# 118  Return to Glory  Pacts of Blood and Might  In Time We Trust
#
#     Spotify Listeners In tour? When? Where?
# ID
# 118             15331       No   NaN    NaN
#
# [1 rows x 21 columns]

# %% [markdown]
# #### Change colum values to INT

# %%
bands.dtypes
# Out:
# Band Name                 object
# Genre                     object
# Year Formed               object
# Founded In                object
# Country                   object
# N° of Albums              object
# N° of Singles             object
# Newest Album              object
# Year                      object
# N°1 Most Popular Album    object
# 2° Most Popular Album     object
# 3° Most Popular Album     object
# Top Song                  object
# 2° Top Song               object
# 3° Top Song               object
# 4° Top Song               object
# 5° Top Song               object
# Spotify Listeners         object
# In tour?                  object
# When?                     object
# Where?                    object
# dtype: object

# %%
bands['Year Formed'] = bands['Year Formed'].fillna(0)
bands['N° of Albums'] = bands['N° of Albums'].fillna(0)
bands['N° of Singles'] = bands['N° of Singles'].fillna(0)
bands['Year'] = bands['Year'].fillna(0)
bands["When?"] = bands["When?"].fillna(0)

# %%
bands['N° of Albums'] = bands['N° of Albums'].astype(int)
bands['N° of Singles'] = bands['N° of Singles'].astype(int)
bands['Year'] = bands['Year'].astype(int)
bands["Spotify Listeners"] = bands["Spotify Listeners"].astype(int)
bands["When?"] = bands["When?"].astype(str)
bands['Year Formed'] = bands['Year Formed'].astype(int)

# %%
bands.dtypes
# Out:
# ID                          int64
# Band Name                  object
# Genre                      object
# Year Formed                 int32
# Founded In                 object
# Country                    object
# N° of Albums                int32
# N° of Singles               int32
# Newest Album               object
# Year                        int32
# N°1 Most Popular Album     object
# 2° Most Popular Album      object
# 3° Most Popular Album      object
# Top Song                   object
# 2° Top Song                object
# 3° Top Song                object
# 4° Top Song                object
# 5° Top Song                object
# Spotify Listeners           int32
# In tour?                   object
# When?                      object
# Where?                     object
# Bands Formed              float64
# dtype: object

# %%
bands
# Out:
#       ID        Band Name                                     Genre  \
# 0      1         Abichova                       Melodic Death Metal
# 1      2    Adorned Brood                                Folk Metal
# 2      3         Alestorm                          Folk/Power Metal
# 3      4  Altars of Grief                  Black/Funeral Doom Metal
# 4      5     Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal
# ..   ...              ...                                       ...
# 119  120           Wisdom                               Power Metal
# 120  121           Wizard                          Epic Power Metal
# 121  122        Wolfchant                          Pagan/Folk Metal
# 122  123        Wolfheart                       Melodic Death Metal
# 123  124          Wulfgar                       Melodic Death Metal
#
#      Year Formed                   Founded In         Country  N° of Albums  \
# ...

# %% [markdown]
# #### Streamline "Where?" column values

# %%
bands['Where?'].value_counts()
# Out:
# EU                           38
# US                            4
# EU/US                         3
# South America & Australia     1
# Canada                        1
# US/EU                         1
# USA/EU                        1
# SA                            1
# AU                            1
# Name: Where?, dtype: int64

# %%
bands[bands["Where?"] == "South America & Australia"]
# Out:
#    Band Name             Genre  Year Formed Founded In         Country  \
# ID
# 3   Alestorm  Folk/Power Metal         2007  Perth, UK  United Kingdom
#
#     N° of Albums  N° of Singles                  Newest Album  Year  \
# ID
# 3              7             15  Seventh Rum of a Seventh Rum  2022
#
#           N°1 Most Popular Album  ... 3° Most Popular Album Top Song  \
# ID                                ...
# 3   Seventh Rum of a Seventh Rum  ...  No Grave but the Sea    Drink
#
#               2° Top Song 3° Top Song            4° Top Song  5° Top Song  \
# ID
# 3   Fucked with an Anchor  Keelhauled  The Sunking Norwegian  Shipwrecked
#
#    Spotify Listeners  In tour? When?                     Where?
# ID
# 3             844394       Yes  2022  South America & Australia
#
# [1 rows x 21 columns]

# %%
bands.loc[3, ["Where?"]] = ["SA/AU"]

# %%
bands['Where?'].value_counts()
# Out:
# EU        38
# US         4
# EU/US      3
# SA/AU      1
# Canada     1
# US/EU      1
# USA/EU     1
# SA         1
# AU         1
# Name: Where?, dtype: int64

# %%
bands[bands["Where?"] == "Canada"]
# Out:
#           Band Name                     Genre  Year Formed  Founded In  \
# ID
# 4   Altars of Grief  Black/Funeral Doom Metal         2013  Regina, CA
#
#    Country  N° of Albums  N° of Singles          Newest Album  Year  \
# ID
# 4   Canada             3              1  This Shameful Burden  2018
#
#    N°1 Most Popular Album  ... 3° Most Popular Album   Top Song 2° Top Song  \
# ID                         ...
# 4                    Iris  ...  This Shameful Burden  Isolation  Desolation
#
#        3° Top Song 4° Top Song    5° Top Song Spotify Listeners  In tour?  \
# ID
# 4   Child of Light        Iris  Room of Angel               873       Yes
#
#    When?  Where?
# ID
# 4   2022  Canada
#
# [1 rows x 21 columns]

# %%
bands.loc[4, ["Where?"]] = ["CA"]

# %%
bands['Where?'].value_counts()
# Out:
# EU        38
# US         4
# EU/US      3
# SA/AU      1
# CA         1
# US/EU      1
# USA/EU     1
# SA         1
# AU         1
# Name: Where?, dtype: int64

# %%
bands[bands["Where?"] == "USA/EU"]
# Out:
#        Band Name              Genre  Year Formed    Founded In  Country  \
# ID
# 10  Battle Beast  Heavy/Power Metal         2005  Helsinki, FL  Finland
#
#     N° of Albums  N° of Singles    Newest Album  Year N°1 Most Popular Album  \
# ID
# 10             6              6  Circus of Doom  2022                  Steel
#
#     ... 3° Most Popular Album        Top Song 2° Top Song  \
# ID  ...
# 10  ...         Unholy Savior  King for a Day        Eden
#
#               3° Top Song                4° Top Song         5° Top Song  \
# ID
# 10  Straight to the Heart  No More Hollywood Endings  Master of Illusion
#
#    Spotify Listeners  In tour? When?  Where?
# ID
# 10            758216       Yes  2022  USA/EU
#
# [1 rows x 21 columns]

# %%
bands.loc[4, ["Where?"]] = ["EU/US"]
bands.loc[10, ["Where?"]] = ["EU/US"]

# %%
bands['Where?'].value_counts()
# Out:
# EU       38
# EU/US     5
# US        4
# SA/AU     1
# US/EU     1
# SA        1
# AU        1
# Name: Where?, dtype: int64

# %%
bands[bands["Where?"] == "US/EU"]
# Out:
#        Band Name                                     Genre  Year Formed  \
# ID
# 5   Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal         2004
#
#      Founded In        Country  N° of Albums  N° of Singles      Newest Album  \
# ID
# 5   Orlando, US  United States             7             23  Walk the Sky 2.0
#
#     Year N°1 Most Popular Album  ... 3° Most Popular Album    Top Song  \
# ID                               ...
# 5   2020        One Day Remains  ...              Fortress  Metalingus
#
#        2° Top Song    3° Top Song     4° Top Song       5° Top Song  \
# ID
# 5   Watch Over You  Silver Tongue  Oper Your Eyes  In Loving Memory
#
#    Spotify Listeners  In tour?      When? Where?
# ID
# 5            2053434       Yes  2022/2023  US/EU
#
# [1 rows x 21 columns]

# %%
bands.loc[5, ["Where?"]] = ["EU/US"]

# %%
bands['Where?'].value_counts()
# Out:
# EU       38
# EU/US     6
# US        4
# SA/AU     1
# SA        1
# AU        1
# Name: Where?, dtype: int64

# %% [markdown]
# ## Analysing Data

# %%
bands
# Out:
#            Band Name                                     Genre  Year Formed  \
# ID
# 1           Abichova                       Melodic Death Metal         2005
# 2      Adorned Brood                                Folk Metal         1993
# 3           Alestorm                          Folk/Power Metal         2007
# 4    Altars of Grief                  Black/Funeral Doom Metal         2013
# 5       Alter Bridge  Hard Rock/ Heavy Metal/Alternative Metal         2004
# ..               ...                                       ...          ...
# 121           Wizard                          Epic Power Metal         1989
# 122        Wolfchant                          Pagan/Folk Metal         2003
# 123        Wolfheart                       Melodic Death Metal         2013
# 124          Wulfgar                       Melodic Death Metal         2005
# 125       Übermensch                  Metalcore/Historic Metal            0
#
# ...

# %%
bands['Country'].value_counts()
# Out:
# Germany                        37
# Sweden                         18
# Finland                        13
# United Kingdom                  8
# Norway                          8
# United States                   7
# Italy                           5
# Denmark                         3
# France                          3
# Ireland                         2
# Hungary                         2
# Switzerland                     2
# Argentina                       2
# Austria                         2
# Canada                          1
# Brazil                          1
# Netherlands                     1
# Denmark, Germany and Norway     1
# Faroe Islands/Denmark           1
# Poland                          1
# Russia                          1
# Spain                           1
# Belgium                         1
# Denmark/Faroe Islands           1
# Australia                       1
# Germany/Austria/Switzerland     1
# Name: Country, dtype: int64

# %%
labels = [
    "Germany", 
    "Sweden",
    "Finland",
    "United Kingdom",
    "Denmark & Territories"
]
percentage = [
    38,
    18,
    13,
    8,
    5
]
colors = ["#941b0c", "#bb4d00", "#ffba08", "#8b6220", "#2191fb"]

# %%
plt.figure(figsize=(10,10))
plt.pie(
    percentage, 
    labels=labels, 
    colors=colors, 
    explode=(0,0.1,0,0,0.1),
    autopct='%.0f%%'
)
plt.title("Bands Nationalities")
plt.show()

# %% [markdown]
# ## German Bands

# %%
german_bands = bands[bands["Country"] == "Germany"]

# %%
german_bands
# Out:
#       ID                   Band Name  \
# 1      2               Adorned Brood
# 8      9                    Asenblut
# 12    13               Black Messiah
# 13    14              Blind Guardian
# 20    21                     Craving
# 29    30  Die Apokalyptischen Reiter
# 32    33                 Dragonsifre
# 38    39                 Equilibrium
# 39    40                  Falkenbach
# 40    41                  Far Beyond
# 41    42                    Feindnah
# 44    45                 Finterfrost
# 45    46                Freedom Call
# 53    54                Grave Digger
# 60    61                  Helgrindur
# 62    63                   Helloween
# 67    68              Human Fortress
# 68    69           Hunde des Krieges
# 71    72                  In Extremo
# 76    77                  Lass Leben
# 81    82                      Menhir
# 86    87                       Mærer
# 89    90                    Nothgard
# 90    91                  Orden Ogan
# ...

# %%
german_bands.drop(124, inplace=True)
german_bands.drop(92, inplace=True)
german_bands.drop(76, inplace=True)
german_bands.drop(41, inplace=True)
# Out:
# C:\Users\Skout\AppData\Local\Temp\ipykernel_3456\2278457922.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   german_bands.drop(124, inplace=True)
# C:\Users\Skout\AppData\Local\Temp\ipykernel_3456\2278457922.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   german_bands.drop(92, inplace=True)
# C:\Users\Skout\AppData\Local\Temp\ipykernel_3456\2278457922.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
german_bands.sort_values('Year Formed')
# Out:
#                       Band Name  \
# 53                 Grave Digger
# 114                     Warlock
# 62                    Helloween
# 13               Blind Guardian
# 120                      Wizard
# 39                   Falkenbach
# 12                Black Messiah
# 1                 Adorned Brood
# 71                   In Extremo
# 29   Die Apokalyptischen Reiter
# 81                       Menhir
# 90                   Orden Ogan
# 99                 Stormwarrior
# 45                 Freedom Call
# 67               Human Fortress
# 32                  Dragonsifre
# 103                 Thrudvangar
# 95                    Rebellion
# 38                  Equilibrium
# 40                   Far Beyond
# 121                   Wolfchant
# 93                    Powerwolf
# 44                  Finterfrost
# 109                        Varg
# 111               Waldgeflüster
# 20                      Craving
# 8                      Asenblut
# 117                 Winterstorm
# ...

# %%
german_bands["Year Formed"].max()
# Out:
# 2019

# %%
swedish_bands.value_counts("Year Formed").min()
# Out:
# 1

# %%
german_bands.value_counts("Year Formed")
# Out:
# Year Formed
# 1995    3
# 2001    3
# 2005    2
# 1989    2
# 2009    2
# 1998    2
# 1999    2
# 1983    2
# 2006    2
# 2004    2
# 1980    1
# 2012    1
# 2011    1
# 2008    1
# 2000    1
# 2003    1
# 1996    1
# 1993    1
# 1992    1
# 1984    1
# 2019    1
# dtype: int64

# %%
german_bands_latest_release=german_bands[['Band Name', 'Year']]

# %%
german_bands_latest_release.dtypes
# Out:
# Band Name    object
# Year          int32
# dtype: object

# %%
german_bands_latest_release['Year'] = german_bands_latest_release['Year'].astype(int)
# Out:
# C:\Users\ehub9_\AppData\Local\Temp\ipykernel_17184\436282432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   german_bands_latest_release['Year'] = german_bands_latest_release['Year'].astype(int)

# %%
german_bands_latest_release.drop(122, inplace=True)
# Out:
# C:\Users\ehub9_\AppData\Local\Temp\ipykernel_17184\797252705.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   german_bands_latest_release.drop(122, inplace=True)

# %%
german_bands_latest_release.drop(86, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [165], in <cell line: 1>()
# ----> 1 german_bands_latest_release.drop(86, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
german_bands_latest_release
# Out:
#                       Band Name  Year
# ID
# 2                 Adorned Brood  2012
# 9                      Asenblut  2020
# 13                Black Messiah  2017
# 14               Blind Guardian  2022
# 21                      Craving  2016
# 30   Die Apokalyptischen Reiter  2022
# 33                  Dragonsifre  2015
# 39                  Equilibrium  2019
# 40                   Falkenbach  2013
# 41                   Far Beyond  2016
# 42                     Feindnah  2021
# 45                  Finterfrost  2019
# 46                 Freedom Call  2019
# 54                 Grave Digger  2022
# 61                   Helgrindur  2017
# 63                    Helloween  2021
# 68               Human Fortress  2019
# 69            Hunde des Krieges  2014
# 72                   In Extremo  2020
# 77                   Lass Leben  2020
# 82                       Menhir  2017
# 87                        Mærer     0
# 90                     Nothgard  2018
# ...

# %% [markdown]
# ## Swedish Bands

# %%
swedish_bands = bands[bands["Country"] == "Sweden"]

# %%
swedish_bands.drop(6, inplace=True)
# Out:
# C:\Users\Skout\AppData\Local\Temp\ipykernel_3456\3318021647.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   swedish_bands.drop(6, inplace=True)

# %%
swedish_bands["Band Name"]
# Out:
# 5            Amon Amarth
# 14            Bloodbound
# 15     Brothers of Metal
# 19             Civil War
# 24     Dark Tranquillity
# 42                  Fejd
# 47           Gallows End
# 48              Garmarna
# 51                 Ghost
# 55               Grimner
# 56            HammerFall
# 64           Hindarfjäll
# 73                Kaunan
# 74        King of Asgard
# 85              Månegarm
# 97               Sabaton
# 104             Thyrfing
# Name: Band Name, dtype: object

# %%
swedish_bands["N° of Albums"]
# Out:
# 5      12
# 14      9
# 15      3
# 19      6
# 24     19
# 42      4
# 47      1
# 48      7
# 51      5
# 55      4
# 56     12
# 64      2
# 73      1
# 74      5
# 85     10
# 97     11
# 104     8
# Name: N° of Albums, dtype: int64

# %%
swedish_bands
# Out:
#              Band Name                       Genre  Year Formed  \
# 5          Amon Amarth         Melodic Death Metal         1992
# 14          Bloodbound           Heavy/Power Metal         2004
# 15   Brothers of Metal           Heavy/Power Metal         2012
# 19           Civil War           Heavy/Power Metal         2012
# 24   Dark Tranquillity         Melodic Death Metal         1991
# 42                Fejd                  Folk Metal         2001
# 47         Gallows End                 Heavy Metal         2007
# 48            Garmarna                   Folk Rock         1990
# 51               Ghost            Heavy Metal/Rock         2006
# 55             Grimner           Folk/Viking Metal         2008
# 56          HammerFall           Heavy/Power Metal         1993
# 64         Hindarfjäll                    Neo Folk         2019
# 73              Kaunan                    Neo Folk         2017
# 74      King of Asgard  Viking/Melodic Death Metal         2008
# ...

# %% [markdown]
# ## Finnish Bands

# %%
finnish_bands = bands[bands["Country"] == "Finland"]

# %%
finnish_bands
# Out:
#          Band Name                                Genre  Year Formed  \
# ID
# 10    Battle Beast                    Heavy/Power Metal         2005
# 11      Battlelore                 Epic Symphonic Metal         1999
# 17          Brymir  Symphonic/Melodic Death/Pagan Metal         2006
# 34       Dreamtale                  Melodic Power Metal         2012
# 38       Ensiferum                      Epic Folk Metal         1995
# 44       Finntroll                 Blackened Folk Metal         1997
# 76     Korpiklaani                           Folk Metal         2003
# 101   Stratovarius                  Melodic Power Metal         1985
# 103   The Declawed                  Melodic Death Metal         2020
# 108  Valonkantajat                  Melodic Heavy Metal         2010
# 119      Wintersun        Symphonic Melodic Death Metal         2003
# 123      Wolfheart                  Melodic Death Metal         2013
# ...

# %% [markdown]
# ## British Bands

# %%
british_bands = bands[bands["Country"] == "United Kingdom"]

# %%
british_bands
# Out:
#           Band Name                  Genre  Year Formed       Founded In  \
# ID
# 3          Alestorm       Folk/Power Metal         2007        Perth, UK
# 27      Def Leppard            Heavy Metal         1977    Sheffield, UK
# 29     Diamond Head  Heavy Metal/Hard Rock         1976  Stourbridge, UK
# 32      DragonForce            Power Metal         1999       London, UK
# 51      George Ezra         Folk Pop/Blues         2013       London, UK
# 53      Gloryhammer  Symphonic Power Metal         2010     Scotland, UK
# 84   My Dying Bride             Doom Metal         1990      Halifax, UK
# 116       Waylander      Celtic Folk Metal         1993       Armagh, UK
#
#             Country  N° of Albums  N° of Singles  \
# ID
# 3    United Kingdom             7             15
# 27   United Kingdom            20             30
# 29   United Kingdom             9              5
# 32   United Kingdom             8              0
# 51   United Kingdom             3             17
# ...

# %% [markdown]
# ## Danish Bands

# %%
danish_bands = bands[bands["Country"] == "Denmark"]

# %%
danish_bands
# Out:
#     Band Name              Genre  Year Formed      Founded In  Country  \
# ID
# 24    Danheim       Ambient Folk         2016  Copenhagen, DK  Denmark
# 102  Svartsot         Folk Metal         2005     Randers, DK  Denmark
# 109     Vanir  Viking/Folk Metal         2009    Roskilde, DK  Denmark
#
#      N° of Albums  N° of Singles Newest Album  Year N°1 Most Popular Album  \
# ID
# 24              8             36     Domadagr  2021               Skapanir
# 102             5              1        Kumbl  2022          Ravnenes saga
# 109             6              8        Sagas  2022              Aldar Rök
#
#      ... 3° Most Popular Album           Top Song       2° Top Song  \
# ID   ...
# 24   ...              Hringrás          Berserkir     Ivars Revenge
# 102  ...                Vældet          Gravollet         Midsommer
# 109  ...         Særimners kød  Sons of the North  Raise Your Horns
#
#             3° Top Song         4° Top Song              5° Top Song  \
# ID
# ...

# %%
bands['Country'].value_counts()
# Out:
# Germany                        37
# Sweden                         18
# Finland                        13
# United Kingdom                  8
# Norway                          8
# United States                   7
# Italy                           5
# Denmark                         3
# France                          3
# Ireland                         2
# Hungary                         2
# Switzerland                     2
# Argentina                       2
# Austria                         2
# Canada                          1
# Brazil                          1
# Netherlands                     1
# Denmark, Germany and Norway     1
# Faroe Islands/Denmark           1
# Poland                          1
# Russia                          1
# Spain                           1
# Belgium                         1
# Denmark/Faroe Islands           1
# Australia                       1
# Germany/Austria/Switzerland     1
# Name: Country, dtype: int64

# %%
tyr = bands.loc[bands['Country'] =='Denmark/Faroe Islands']

# %%
danish_bands = danish_bands.append(tyr)
# Out:
# C:\Users\ehub9_\AppData\Local\Temp\ipykernel_17184\3749244560.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   danish_bands = danish_bands.append(tyr)

# %%
Heljareyga = bands.loc[bands['Country'] =='Faroe Islands/Denmark']

# %%
danish_bands = danish_bands.append(Heljareyga)
# Out:
# C:\Users\ehub9_\AppData\Local\Temp\ipykernel_17184\1798980758.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   danish_bands = danish_bands.append(Heljareyga)

# %%
danish_bands
# Out:
#       Band Name                   Genre  Year Formed      Founded In  \
# ID
# 24      Danheim            Ambient Folk         2016  Copenhagen, DK
# 102    Svartsot              Folk Metal         2005     Randers, DK
# 109       Vanir       Viking/Folk Metal         2009    Roskilde, DK
# 106         Týr              Folk Metal         1998  Copenhagen, DK
# 62   Heljareyga  Folk/Progressive Metal         1983     Hamburg, DE
#
#                    Country  N° of Albums  N° of Singles Newest Album  Year  \
# ID
# 24                 Denmark             8             36     Domadagr  2021
# 102                Denmark             5              1        Kumbl  2022
# 109                Denmark             6              8        Sagas  2022
# 106  Denmark/Faroe Islands             8              0          Hel  2019
# 62   Faroe Islands/Denmark             1              0   Heljareyga  2010
#
#                 N°1 Most Popular Album  ... 3° Most Popular Album  \
# ...

# %% [markdown]
# ### Country with the most bands

# %%
bands.Country.value_counts().plot(
    kind="bar", 
    title="Country with the most bands", fontsize="10")
plt.xlabel("NationalityBands", fontsize=24)
plt.ylabel("Bands", fontsize=24)
# Out:
# Text(0, 0.5, 'Bands')

# %% [markdown]
# ### Bands founded in the same city

# %%
bands['Founded In'].value_counts().head(13)
# Out:
# Helsinki, FI        5
# Stockholm, SE       5
# Copenhagen, DK      4
# ,DE                 3
# Hamburg, DE         3
# Bergen, NO          2
# Dublin, IE          2
# Gothenburg, SE      2
# Lahti, FI           2
# Buenos Aires, AR    2
# , DE                2
# London, UK          2
# Åsa, NO             1
# Name: Founded In, dtype: int64

# %%
labels = ["Copenhagen, DK", "Helsinki, FI", "Stockholm, SE","Buenos Aires, AR", "Lahti, FI", "Gothenburg, SE", "Bergen, NO", "Hamburg, DE", "London, UK", "Dublin, IE"]
ammount =[4,4,4,3,2,2,2,2,2,2]
colors = ["#095256", "#3A4F41", "#5AAA95", "#90A9B7", "#8DFFCD","#087F8C", "#2B50AA", "#F26419", "#3A4F41", "#BB9F06"]

# %%
plt.figure(figsize=(10,10))
plt.pie(
    ammount,
    labels=labels,
    colors=colors,
    explode=(0,0.05,0,0,0.01,0,0,0,0.5,0.5),
    autopct='%.0f%%')
    
plt.title("Cities")
plt.show()

# %% [markdown]
# ### Year with most Swedish bands formed

# %%
swedish_bands.drop(6, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [46], in <cell line: 1>()
# ----> 1 swedish_bands.drop(6, inplace=True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
#    4817     """
# ...

# %%
swedish_bands
# Out:
#              Band Name                       Genre  Year Formed  \
# 5          Amon Amarth         Melodic Death Metal         1992
# 14          Bloodbound           Heavy/Power Metal         2004
# 15   Brothers of Metal           Heavy/Power Metal         2012
# 19           Civil War           Heavy/Power Metal         2012
# 24   Dark Tranquillity         Melodic Death Metal         1991
# 42                Fejd                  Folk Metal         2001
# 47         Gallows End                 Heavy Metal         2007
# 48            Garmarna                   Folk Rock         1990
# 51               Ghost            Heavy Metal/Rock         2006
# 55             Grimner           Folk/Viking Metal         2008
# 56          HammerFall           Heavy/Power Metal         1993
# 64         Hindarfjäll                    Neo Folk         2019
# 73              Kaunan                    Neo Folk         2017
# 74      King of Asgard  Viking/Melodic Death Metal         2008
# ...

# %%
swedish_bands_by_year = swedish_bands[["Band Name", "Year Formed"]].sort_values("Year Formed")

# %%
swedish_bands_by_year
# Out:
#              Band Name  Year Formed
# 48            Garmarna         1990
# 24   Dark Tranquillity         1991
# 5          Amon Amarth         1992
# 56          HammerFall         1993
# 97             Sabaton         1993
# 85            Månegarm         1995
# 104           Thyrfing         1995
# 42                Fejd         2001
# 14          Bloodbound         2004
# 51               Ghost         2006
# 47         Gallows End         2007
# 55             Grimner         2008
# 74      King of Asgard         2008
# 19           Civil War         2012
# 15   Brothers of Metal         2012
# 73              Kaunan         2017
# 64         Hindarfjäll         2019

# %%
plt.figure(figsize=(30,5))
sns.lineplot(data=swedish_bands_by_year, x="Band Name", y="Year Formed")
# Out:
# <AxesSubplot:xlabel='Band Name', ylabel='Year Formed'>

# %% [markdown]
# ### Year with the most album releases

# %%
most_album_realeases = bands[["Band Name", "Year"]].sort_values("Year")

# %%
most_album_realeases
# Out:
#         Band Name  Year
# 124    Übermensch     0
# 86          Mærer     0
# 114       Warlock  1987
# 30            Dio  2004
# 78          Lumsk  2007
# ..            ...   ...
# 100  Stratovarius  2022
# 50    George Ezra  2022
# 6     Amon Amarth  2022
# 51          Ghost  2022
# 10     Battlelore  2022
#
# [125 rows x 2 columns]

# %%
most_album_realeases.drop(122, inplace = True)

# %%
most_album_realeases.drop(86, inplace = True)

# %%
most_album_realeases.drop(125, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [55], in <cell line: 1>()
# ----> 1 most_album_realeases.drop(125, inplace = True)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4806 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4807 def drop(
#    4808     self,
#    (...)
#    4815     errors: str = "raise",
#    4816 ):
# ...

# %%
most_album_realeases.drop(87, inplace = True)

# %%
most_album_realeases
# Out:
#         Band Name  Year
# 124    Übermensch     0
# 114       Warlock  1987
# 30            Dio  2004
# 78          Lumsk  2007
# 47    Gallows End  2010
# ..            ...   ...
# 100  Stratovarius  2022
# 50    George Ezra  2022
# 6     Amon Amarth  2022
# 51          Ghost  2022
# 10     Battlelore  2022
#
# [122 rows x 2 columns]

# %%
year_data = most_album_realeases.value_counts("Year")

# %%
p = sns.kdeplot(data=year_data, x=(1987, 2022))
p.set_xlabel("Year Formed", fontsize = 20)
p.set_ylabel("Bands formed", fontsize = 20)
# Out:
# Text(0, 0.5, 'Bands formed')

# %% [markdown]
# ### Current year album releases

# %%
bands[["Year"]].value_counts("Year").head(1)
# Out:
# Year
# 2022    26
# dtype: int64

# %%
bands.to_csv("C:\\Users\\ehub9_\\Desktop\\Datasets\\Bands\\finishedbands.csv")

# %%
euro_bands = [german_bands, swedish_bands, finnish_bands, british_bands, danish_bands]

# %%
euro_bands
# Out:
# [                      Band Name  \
#  ID
#  2                 Adorned Brood
#  9                      Asenblut
#  13                Black Messiah
#  14               Blind Guardian
#  21                      Craving
#  30   Die Apokalyptischen Reiter
#  33                  Dragonsifre
#  39                  Equilibrium
#  40                   Falkenbach
#  41                   Far Beyond
#  42                     Feindnah
#  45                  Finterfrost
#  46                 Freedom Call
#  54                 Grave Digger
#  61                   Helgrindur
#  63                    Helloween
#  68               Human Fortress
#  69            Hunde des Krieges
#  72                   In Extremo
#  77                   Lass Leben
#  82                       Menhir
#  87                        Mærer
#  90                     Nothgard
#  91                   Orden Ogan
#  93                       Phönix
#  94                    Powerwolf
#  96                    Rebellion
# ...
